# %%
print("hello,taobao project")
# Out:
# hello,taobao project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("pandas version:",pd.__version__)
print("数据分析环境测试成功")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# pandas version: 2.3.3
# 数据分析环境测试成功

# %%
from pathlib import Path
project_path = Path.home() / "Desktop" / "taobao-user-behavior-analysis"

folders = [
    project_path / "data" / "raw",
    project_path / "data" / "processed",
    project_path / "notebooks",
    project_path / "outputs" / "figures",
    project_path / "outputs" / "tables"
]

for folder in folders:
    folder.mkdir(parents=True, exist_ok=True)

print("项目文件夹创建完成：", project_path)
# Out:
# 项目文件夹创建完成： /Users/liuyixiao/Desktop/taobao-user-behavior-analysis
